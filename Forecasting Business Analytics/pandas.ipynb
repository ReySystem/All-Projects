# %%
#PANDAS - exploratory data analysis (EDA)

# %%
import pandas as pd

# %%
#SERIES 
#DATAFRAME

# %%
import numpy as np

# %%
data = np.array(['abc','abc1','abc2','abc3'])
series1 = pd.Series(data)
series1
# Out:
# 0     abc
# 1    abc1
# 2    abc2
# 3    abc3
# dtype: object

# %%
type(series1)
# Out:
# pandas.core.series.Series

# %%
#DATAFRAME

# %%
df = pd.read_table('/content/fruit_data_with_colors.txt')
df
# Out:
#     fruit_label fruit_name     fruit_subtype  mass  width  height  color_score
# 0             1      apple      granny_smith   192    8.4     7.3         0.55
# 1             1      apple      granny_smith   180    8.0     6.8         0.59
# 2             1      apple      granny_smith   176    7.4     7.2         0.60
# 3             2   mandarin          mandarin    86    6.2     4.7         0.80
# 4             2   mandarin          mandarin    84    6.0     4.6         0.79
# 5             2   mandarin          mandarin    80    5.8     4.3         0.77
# 6             2   mandarin          mandarin    80    5.9     4.3         0.81
# 7             2   mandarin          mandarin    76    5.8     4.0         0.81
# 8             1      apple          braeburn   178    7.1     7.8         0.92
# 9             1      apple          braeburn   172    7.4     7.0         0.89
# 10            1      apple          braeburn   166    6.9     7.3         0.93
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   fruit_label    59 non-null     int64
#  1   fruit_name     59 non-null     object
#  2   fruit_subtype  59 non-null     object
#  3   mass           59 non-null     int64
#  4   width          59 non-null     float64
#  5   height         59 non-null     float64
#  6   color_score    59 non-null     float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 3.4+ KB

# %%
df.shape
# Out:
# (59, 7)

# %%
df.size
# Out:
# 413

# %%
59*7
# Out:
# 413

# %%
df.head()
# Out:
#    fruit_label fruit_name fruit_subtype  mass  width  height  color_score
# 0            1      apple  granny_smith   192    8.4     7.3         0.55
# 1            1      apple  granny_smith   180    8.0     6.8         0.59
# 2            1      apple  granny_smith   176    7.4     7.2         0.60
# 3            2   mandarin      mandarin    86    6.2     4.7         0.80
# 4            2   mandarin      mandarin    84    6.0     4.6         0.79

# %%
df.head() #prints first 5 values
# Out:
#    fruit_label fruit_name fruit_subtype  mass  width  height  color_score
# 0            1      apple  granny_smith   192    8.4     7.3         0.55
# 1            1      apple  granny_smith   180    8.0     6.8         0.59
# 2            1      apple  granny_smith   176    7.4     7.2         0.60
# 3            2   mandarin      mandarin    86    6.2     4.7         0.80
# 4            2   mandarin      mandarin    84    6.0     4.6         0.79

# %%
df.head(10)  #prints first 10 values
# Out:
#    fruit_label fruit_name fruit_subtype  mass  width  height  color_score
# 0            1      apple  granny_smith   192    8.4     7.3         0.55
# 1            1      apple  granny_smith   180    8.0     6.8         0.59
# 2            1      apple  granny_smith   176    7.4     7.2         0.60
# 3            2   mandarin      mandarin    86    6.2     4.7         0.80
# 4            2   mandarin      mandarin    84    6.0     4.6         0.79
# 5            2   mandarin      mandarin    80    5.8     4.3         0.77
# 6            2   mandarin      mandarin    80    5.9     4.3         0.81
# 7            2   mandarin      mandarin    76    5.8     4.0         0.81
# 8            1      apple      braeburn   178    7.1     7.8         0.92
# 9            1      apple      braeburn   172    7.4     7.0         0.89

# %%
df.tail()  # prints last 5 values
# Out:
#     fruit_label fruit_name fruit_subtype  mass  width  height  color_score
# 54            4      lemon       unknown   116    6.1     8.5         0.71
# 55            4      lemon       unknown   116    6.3     7.7         0.72
# 56            4      lemon       unknown   116    5.9     8.1         0.73
# 57            4      lemon       unknown   152    6.5     8.5         0.72
# 58            4      lemon       unknown   118    6.1     8.1         0.70

# %%
df.tail(8)  #prints the last 8 values of df
# Out:
#     fruit_label fruit_name fruit_subtype  mass  width  height  color_score
# 51            4      lemon       unknown   116    6.0     7.5         0.72
# 52            4      lemon       unknown   118    5.9     8.0         0.72
# 53            4      lemon       unknown   120    6.0     8.4         0.74
# 54            4      lemon       unknown   116    6.1     8.5         0.71
# 55            4      lemon       unknown   116    6.3     7.7         0.72
# 56            4      lemon       unknown   116    5.9     8.1         0.73
# 57            4      lemon       unknown   152    6.5     8.5         0.72
# 58            4      lemon       unknown   118    6.1     8.1         0.70

# %%
df[23:29]   #inclusive and exclusive (slicing)
# Out:
#     fruit_label fruit_name     fruit_subtype  mass  width  height  color_score
# 23            1      apple       cripps_pink   170    7.6     7.9         0.88
# 24            3     orange     spanish_jumbo   342    9.0     9.4         0.75
# 25            3     orange     spanish_jumbo   356    9.2     9.2         0.75
# 26            3     orange     spanish_jumbo   362    9.6     9.2         0.74
# 27            3     orange  selected_seconds   204    7.5     9.2         0.77
# 28            3     orange  selected_seconds   140    6.7     7.1         0.72

# %%
df.iloc[0:5,1:4] #integer-location based indexing for selection by position.
# Out:
#   fruit_name fruit_subtype  mass
# 0      apple  granny_smith   192
# 1      apple  granny_smith   180
# 2      apple  granny_smith   176
# 3   mandarin      mandarin    86
# 4   mandarin      mandarin    84

# %%
df.iloc[:] #prints the entire df
df.iloc[:,:] #prints entire df
# Out:
#     fruit_label fruit_name     fruit_subtype  mass  width  height  color_score
# 0             1      apple      granny_smith   192    8.4     7.3         0.55
# 1             1      apple      granny_smith   180    8.0     6.8         0.59
# 2             1      apple      granny_smith   176    7.4     7.2         0.60
# 3             2   mandarin          mandarin    86    6.2     4.7         0.80
# 4             2   mandarin          mandarin    84    6.0     4.6         0.79
# 5             2   mandarin          mandarin    80    5.8     4.3         0.77
# 6             2   mandarin          mandarin    80    5.9     4.3         0.81
# 7             2   mandarin          mandarin    76    5.8     4.0         0.81
# 8             1      apple          braeburn   178    7.1     7.8         0.92
# 9             1      apple          braeburn   172    7.4     7.0         0.89
# 10            1      apple          braeburn   166    6.9     7.3         0.93
# ...

# %%
df.iloc[:,-1] #prints only the last column of the dataframe as a series
# Out:
# 0     0.55
# 1     0.59
# 2     0.60
# 3     0.80
# 4     0.79
# 5     0.77
# 6     0.81
# 7     0.81
# 8     0.92
# 9     0.89
# 10    0.93
# 11    0.92
# 12    0.88
# 13    0.70
# 14    0.69
# 15    0.69
# 16    0.67
# 17    0.73
# 18    0.83
# 19    0.85
# 20    0.86
# 21    0.84
# 22    0.87
# 23    0.88
# 24    0.75
# 25    0.75
# 26    0.74
# 27    0.77
# 28    0.72
# 29    0.81
# 30    0.79
# 31    0.82
# 32    0.80
# 33    0.74
# 34    0.75
# 35    0.75
# 36    0.76
# 37    0.79
# 38    0.77
# 39    0.75
# 40    0.78
# 41    0.79
# 42    0.82
# 43    0.70
# 44    0.72
# 45    0.72
# 46    0.71
# 47    0.72
# 48    0.72
# 49    0.73
# 50    0.71
# 51    0.72
# 52    0.72
# 53    0.74
# 54    0.71
# 55    0.72
# 56    0.73
# 57    0.72
# 58    0.70
# Name: color_score, dtype: float64

# %%
df.iloc[:,-1].values #prints only the last column of the dataframe as an array
# Out:
# array([0.55, 0.59, 0.6 , 0.8 , 0.79, 0.77, 0.81, 0.81, 0.92, 0.89, 0.93,
#        0.92, 0.88, 0.7 , 0.69, 0.69, 0.67, 0.73, 0.83, 0.85, 0.86, 0.84,
#        0.87, 0.88, 0.75, 0.75, 0.74, 0.77, 0.72, 0.81, 0.79, 0.82, 0.8 ,
#        0.74, 0.75, 0.75, 0.76, 0.79, 0.77, 0.75, 0.78, 0.79, 0.82, 0.7 ,
#        0.72, 0.72, 0.71, 0.72, 0.72, 0.73, 0.71, 0.72, 0.72, 0.74, 0.71,
#        0.72, 0.73, 0.72, 0.7 ])

# %%
fname = df.fruit_name
fname

# %%
fname = df.fruit_name.unique() #tells us the unique names 
fname
# Out:
# array(['apple', 'mandarin', 'orange', 'lemon'], dtype=object)

# %%
fsize = df.groupby('fruit_name',sort = False).size()
fsize
# Out:
# fruit_name
# apple       19
# mandarin     5
# orange      19
# lemon       16
# dtype: int64

# %%
import matplotlib.pyplot as plt
plt.bar(fname,fsize)
# Out:
# <BarContainer object of 4 artists>

# %%
df['fruit_name'].value_counts()
# Out:
# orange      19
# apple       19
# lemon       16
# mandarin     5
# Name: fruit_name, dtype: int64

# %%
df.head()
# Out:
#    fruit_label fruit_name fruit_subtype  mass  width  height  color_score
# 0            1      apple  granny_smith   192    8.4     7.3         0.55
# 1            1      apple  granny_smith   180    8.0     6.8         0.59
# 2            1      apple  granny_smith   176    7.4     7.2         0.60
# 3            2   mandarin      mandarin    86    6.2     4.7         0.80
# 4            2   mandarin      mandarin    84    6.0     4.6         0.79

# %%
height = df.height
height
# Out:
# 0      7.3
# 1      6.8
# 2      7.2
# 3      4.7
# 4      4.6
# 5      4.3
# 6      4.3
# 7      4.0
# 8      7.8
# 9      7.0
# 10     7.3
# 11     7.6
# 12     7.1
# 13     7.7
# 14     7.3
# 15     7.1
# 16     7.5
# 17     7.6
# 18     7.1
# 19     7.2
# 20     7.5
# 21     7.4
# 22     7.1
# 23     7.9
# 24     9.4
# 25     9.2
# 26     9.2
# 27     9.2
# 28     7.1
# 29     7.4
# 30     7.5
# 31     8.0
# 32     7.0
# 33     8.1
# 34     7.8
# 35     7.9
# 36     7.6
# 37     7.3
# 38     7.8
# 39     7.4
# 40     7.5
# 41     8.2
# 42     7.2
# 43    10.3
# 44    10.5
# 45     9.2
# 46    10.2
# 47     9.7
# 48    10.1
# 49     8.7
# 50     8.2
# 51     7.5
# 52     8.0
# 53     8.4
# 54     8.5
# 55     7.7
# 56     8.1
# 57     8.5
# 58     8.1
# Name: height, dtype: float64

# %%
width = df['width']

# %%
width
# Out:
# 0     8.4
# 1     8.0
# 2     7.4
# 3     6.2
# 4     6.0
# 5     5.8
# 6     5.9
# 7     5.8
# 8     7.1
# 9     7.4
# 10    6.9
# 11    7.1
# 12    7.0
# 13    7.3
# 14    7.6
# 15    7.7
# 16    7.6
# 17    7.5
# 18    7.5
# 19    7.4
# 20    7.5
# 21    7.4
# 22    7.3
# 23    7.6
# 24    9.0
# 25    9.2
# 26    9.6
# 27    7.5
# 28    6.7
# 29    7.0
# 30    7.1
# 31    7.8
# 32    7.2
# 33    7.5
# 34    7.6
# 35    7.1
# 36    7.1
# 37    7.3
# 38    7.2
# 39    6.8
# 40    7.1
# 41    7.6
# 42    7.2
# 43    7.2
# 44    7.3
# 45    7.2
# 46    7.3
# 47    7.3
# 48    7.3
# 49    5.8
# 50    6.0
# 51    6.0
# 52    5.9
# 53    6.0
# 54    6.1
# 55    6.3
# 56    5.9
# 57    6.5
# 58    6.1
# Name: width, dtype: float64

# %%
plt.scatter(height,width)

# %%
#SEABORN LIBRARY (DATA VISUALIZATION)
#seaborn is based on matplotlib 
import seaborn as sns

# %%
#color palettes 
cols = sns.color_palette()
sns.palplot(cols)

# %%
sns.palplot(sns.color_palette("Blues"))

# %%
sns.palplot(sns.color_palette("Blues_r",15))

# %%
sns.palplot(sns.color_palette("Greens",20))

# %%
sns.palplot(sns.color_palette("Reds",20))

# %%
sns.palplot(sns.color_palette("red",15))

# %%
# 'Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 
# 'Dark2_r','GnBu', 'GnBu_r', 'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 'Oranges', 'Oranges_r', 'PRGn', 'PRGn_r',
#  'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 'PuBu_r',
#  'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu',
#  'RdYlBu_r', 'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r',  'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r', 'Spectral', 'Spectral_r',
#   'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', 'YlGnBu_r', 'YlGn_r',  'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 'afmhot_r',
#    'autumn', 'autumn_r', 'binary', 'binary_r', 'bone', 'bone_r', 'brg','brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 
#    'cool_r', 'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'crest', 'crest_r','cubehelix', 'cubehelix_r', 'flag', 'flag_r',
#     'flare', 'flare_r', 'gist_earth', 'gist_earth_r', 'gist_gray', 'gist_gray_r', 'gist_heat',   'gist_heat_r', 'gist_ncar',
#      'gist_ncar_r', 'gist_rainbow', 'gist_rainbow_r', 'gist_stern', 'gist_stern_r', 'gist_yarg', 'gist_yarg_r','gnuplot',
#       'gnuplot2', 'gnuplot2_r', 'gnuplot_r', 'gray', 'gray_r', 'hot', 'hot_r', 'hsv', 'hsv_r', 'icefire', 'icefire_r', 'inferno',
#      'inferno_r', 'jet', 'jet_r', 'magma...

# %%
sns.palplot(sns.color_palette("cubehelix_r",15))

# %%
sns.palplot(sns.color_palette("cubehelix",15))

# %%
import pandas as pd
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips = sns.load_dataset('tips') #loads the tips dataset from seaborn library 
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#EDA steps for this dataset

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.3 KB

# %%
tips.shape
# Out:
# (244, 7)

# %%
sns.set()  #sets all the default styles for plotting and visuals

# %%
#distribution plot 
sns.distplot(tips['total_bill']) #histogram + kernel density estimate (kde) plot
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(tips['total_bill'], kde = False)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(tips['total_bill'],hist = False)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
sns.scatterplot(x = "total_bill", y = "tip" , data = tips, hue = 'day', s= 200, marker = "*")

# %%
sns.relplot(x = "total_bill", y ="day", data = tips, style = "smoker", hue = "size")

# %%
#joint plot 
sns.jointplot(x = "total_bill", y = "tip",data = tips)
sns.jointplot(x = "total_bill", y = "tip",data = tips, kind = "reg", color = "red")
sns.jointplot(x = "total_bill", y = "tip",data = tips, kind = "resid", color ="green")
sns.jointplot(x = "total_bill", y = "tip",data = tips, kind = "kde", color = "lightblue")
sns.jointplot(x = "total_bill", y = "tip",data = tips, kind = "hex", color = "cyan")

# %%
sns.pairplot(tips)

# %%
sns.stripplot(x = "sex", y = "total_bill", data = tips)

# %%
sns.stripplot(x = "day", y = "total_bill", data = tips)

# %%
sns.swarmplot(x = "sex", y = "total_bill", data = tips)

# %%
sns.swarmplot(x = "day", y = "total_bill", data = tips)

# %%
sns.boxplot(x = "day", y = "total_bill", data = tips)

# %%
sns.boxplot(x = tips['total_bill'])

# %%
sns.boxenplot(x = tips['total_bill'])

# %%
sns.violinplot(x = tips['total_bill'])

# %%
sns.violinplot(x = "day", y = "total_bill", data = tips)

# %%
#categorical plot 
sns.catplot(x = "day", y = "total_bill", data = tips) #default catplot is strip plot
sns.catplot(x = "day", y = "total_bill", data = tips, kind = "swarm")
sns.catplot(x = "day", y = "total_bill", data = tips, kind = "violin")
sns.catplot(x = "day", y = "total_bill", data = tips, kind = "box")
sns.catplot(x = "day", y = "total_bill", data = tips, kind = "boxen")

# %%
#HEATMAPS IN SEABORN

# %%
uniform_data = np.random.rand(10,12)
sns.heatmap(uniform_data, cmap ='icefire', annot = True)

# %%
tips.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
corr1 = tips.corr()
sns.heatmap(corr1)

# %%
#TITANIC DATASET EDA

# %%
df = pd.read_csv('/content/train.csv')
df
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df['Age'][500:510] #Not a number
# Out:
# 500    17.0
# 501    21.0
# 502     NaN
# 503    37.0
# 504    16.0
# 505    18.0
# 506    33.0
# 507     NaN
# 508    28.0
# 509    26.0
# Name: Age, dtype: float64

# %%
df[502:504] #searching for NaN values
# Out:
#      PassengerId  Survived  Pclass  ...    Fare Cabin  Embarked
# 502          503         0       3  ...  7.6292   NaN         Q
# 503          504         0       3  ...  9.5875   NaN         S
#
# [2 rows x 12 columns]

# %%
df.shape
# Out:
# (891, 12)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df = df.drop(['Cabin'], axis = 1)
df
# Out:
#      PassengerId  Survived  Pclass  ...            Ticket     Fare  Embarked
# 0              1         0       3  ...         A/5 21171   7.2500         S
# 1              2         1       1  ...          PC 17599  71.2833         C
# 2              3         1       3  ...  STON/O2. 3101282   7.9250         S
# 3              4         1       1  ...            113803  53.1000         S
# 4              5         0       3  ...            373450   8.0500         S
# ..           ...       ...     ...  ...               ...      ...       ...
# 886          887         0       2  ...            211536  13.0000         S
# 887          888         1       1  ...            112053  30.0000         S
# 888          889         0       3  ...        W./C. 6607  23.4500         S
# 889          890         1       1  ...            111369  30.0000         C
# 890          891         0       3  ...            370376   7.7500         Q
#
# [891 rows x 11 columns]

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         2
# dtype: int64

# %%
df.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Embarked         3
# dtype: int64

# %%
df['Survived'].unique()
# Out:
# array([0, 1])

# %%
df['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt 
import numpy as np

# %%
sns.countplot(x = "Survived", data = df)

# %%
s = df['Survived'].value_counts()
s
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
aa = ['Not Survived', 'Survived']
plt.bar(aa,s)

# %%
s1 = df['Sex'].value_counts()
s1
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
s1.index
# Out:
# Index(['male', 'female'], dtype='object')

# %%
plt.bar(s1.index,s1)
# Out:
# <BarContainer object of 2 artists>

# %%
sns.catplot(x = "Sex", hue = "Survived", kind = 'count', data = df)

# %%
df[df['Survived']==1]['Sex'].value_counts()
# Out:
# female    233
# male      109
# Name: Sex, dtype: int64

# %%
df[df['Survived']==0]['Sex'].value_counts()
# Out:
# male      468
# female     81
# Name: Sex, dtype: int64

# %%
sns.catplot(x = "Sex", y ="Survived", data = df, kind = "violin")

# %%
sns.catplot(x = "Sex", y ="Age", data = df,hue = "Survived", kind = "violin")

# %%
p = df['Pclass'].unique()
p
# Out:
# array([3, 1, 2])

# %%
df['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
df['Age'].isnull().sum()
# Out:
# 177

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 76.7+ KB

# %%
df = df.dropna() # remove null values

# %%
df.shape
# Out:
# (712, 11)

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
np.max(df['Age'])
# Out:
# 80.0

# %%
np.min(df['Age'])
# Out:
# 0.42

# %%
ppl_y = np.count_nonzero((df['Age']>0) & (df['Age']<18))   #0 - 18 age 
ppl_a = np.count_nonzero((df['Age']>=18) & (df['Age']<40)) # 18 to 40 age
ppl_b = np.count_nonzero((df['Age']>=40) & (df['Age']<60)) #40 to 60 age
ppl_c = np.count_nonzero((df['Age']>=60))                  #above 60 yrs

# %%
ppl_y
# Out:
# 113

# %%
ppl_a
# Out:
# 437

# %%
ppl_b
# Out:
# 137

# %%
ppl_c
# Out:
# 25

# %%
reload_model = pickle.load(open('linear_reg.pkl','rb'))

# %%
reload_model.predict([[10.0]])
# Out:
# array([120291.82341322])
